# %%
class stud:
    def __init__(self,sid,sroolno,sec):
        self.sid=sid
        self.sroolno=sroolno
        self.sec=sec
        print("HELLO")

    def record(self):
        print("get sec",self.sec)

# %%
s=stud(2,34,'A')
s.record()
# Out:
# HELLO
# get sec A

# %%
def sum(a,b):
    c=a+b
    print(c)
    return c

res=sum(2,3)

print(res)
# Out:
# 5
# 5

# %%
sum=lambda a,b:a+b
print(sum(2,6))
# Out:
# 8

# %%
#map()

def sq(x):
  return  x*x

l1=[2,3,4,5]

list(map(sq,l1))
# Out:
# [4, 9, 16, 25]

# %%
x=100
type(x)
# Out:
# int

# %%
x='hello'
u='world'
x+u
# Out:
# 'helloworld'

# %%
9//2
9/2
# Out:
# 4.5

# %%
s='Hello. How are you?'
s[7:10]
# Out:
# 'How'

# %%
 '1.2e01'.isdigit()
# Out:
# False

# %%
s='how are you'
s.capitalize()
# Out:
# 'How are you'

# %%
for char in 'Hello':
    print (char,end=",")
# Out:
# H,e,l,l,o,

# %%
a=10
def myfunction():
    a=20
    returnPrint('a=',a)

# %%
sns.
