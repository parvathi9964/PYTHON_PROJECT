# %%
import pandas as pd

df=pd.read_csv("c:/Users/parva/OneDrive/Desktop/COACHX LIVE/PYTHON/PYTHON_PRACTISE/PRACTICAL/startups.csv")

df

# %%
df.head()

# %%
df.tail()

# %%
df.head(7)

# %%
df.shape

# %%
df['PROFIT'].head(3)

# %%
df.loc[2:7,['PROFIT','MKT']]

# %%
df.iloc[3:5,3:5]

# %%
df['STATE'].head(7)

# %%
stud={
    'id':[1,2,3,4],
    'name':['ramya','rama','deepa','charu'],
    'course':['sc','scio','math','geo'],
    'sec':['A','B','A','C'],
    'marks':[100,340,120,250]
}

# %%
st=pd.DataFrame(stud)

st

# %%
st[st['marks']>120]

# %%
st[(st['sec']=='A') & (st['marks']>100)]

# %%
cr=pd.read_csv('c:/Users/parva/OneDrive/Desktop/COACHX LIVE/PYTHON/PYTHON_PRACTISE/PRACTICAL/cars.csv')

cr

# %%
cr.shape

# %%
cr.columns

# %%
#sort value

cr.sort_values(by='Model',ascending=False)

# %%
cr[['Cylinders','AirBags']].sort_values(by='AirBags',ascending=False)

# %%
#group by

cr.columns

# %%
cr.groupby(by='RPM').count()

# %%
cr.groupby(by=['Origin','Wheelbase']).count()

# %%
cr.groupby(by='Price').RPM.sum()

# %%
#missing values

import numpy as np

dff={
    'id':[1,2,np.nan],
    'name':['shat',np.nan,np.nan],
    'dep':['it',np.nan,'cs']
}

d=pd.DataFrame(dff)
d

# %%
d.isnull()

# %%
d.notnull()

# %%
d.isnull().sum()

# %%
#fillin value

d.fillna(0)

# %%
#joints
import pandas as pd
ddpt={
    'deptid':[1,2,3,4,5,6],
    'depname':['cs','it','ec','me','el','ml']
}

dept=pd.DataFrame(ddpt)
dept

# %%
employ={
    'eid':[i for i in range(100,106)],
    'ename':['sa','da','ram','pra','mok','par'],
    'edesignation':['hr','anala','manger','leader','tl','lead'],
    'deptidd':[2,4,5,8,7,2]
}

ep=pd.DataFrame(employ)

ep

# %%
#joints

innerjoin=pd.merge(ep,dept,how='inner' , left_on='deptidd', right_on='deptid')

innerjoin

# %%
ep['ename'].dtype
